# %% [markdown]
# # 1.Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2.Load the file

# %%
df=pd.read_csv("Inc_Exp_Data (1).csv")

# %%
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %% [markdown]
# # 3.Analyze the data

# %%
df.head(5)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
df.tail(5)
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 45            90000             48000                  7                0
# 46            98000             25000                  5                0
# 47           100000             30000                  6                0
# 48           100000             50000                  4            20000
# 49           100000             40000                  6            10000
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 45            885600            Post-Graduate                      3
# 46           1152480             Professional                      2
# 47           1404000                 Graduate                      3
# 48           1032000             Professional                      2
# 49           1320000            Post-Graduate                      1

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
features = df.columns
features
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %% [markdown]
# # 4.What is the Mean Expense of a Household?

# %%
np.mean(df['Mthly_HH_Expense'])
# Out:
# 18818.0

# %% [markdown]
# # 5.What is the Median Household Expense?

# %%
np.median(df['Mthly_HH_Expense'])
# Out:
# 15500.0

# %% [markdown]
# # 6.What is the Monthly Expense for most of the Households?

# %%
monthlyhouseholds = df['Mthly_HH_Expense'].value_counts().index.tolist()[0]
monthlyhouseholds
# Out:
# 25000

# %% [markdown]
# # 7.Plot the Histogram to count the Highest qualified member

# %%
sns.countplot(x="Highest_Qualified_Member",data=df)
# Out:
# <Axes: xlabel='Highest_Qualified_Member', ylabel='count'>

# %% [markdown]
# # 8.Calculate IQR(difference between 75% and 25% quartile)

# %%
for feature in features:
  if df[feature].dtypes != "object":
    IQR = df[feature].quantile(0.75) - df[feature].quantile(0.25)
    print(f"IQR for {feature} is {IQR}")
# Out:
# IQR for Mthly_HH_Income is 26825.0
# IQR for Mthly_HH_Expense is 15000.0
# IQR for No_of_Fly_Members is 2.0
# IQR for Emi_or_Rent_Amt is 3500.0
# IQR for Annual_HH_Income is 335970.0
# IQR for No_of_Earning_Members is 1.0

# %% [markdown]
# # 9.Calculate Standard Deviation for first 4 columns.

# %%
fourcolumns = df.iloc[:,0:4]
for feature in fourcolumns:
  std = np.std(df[feature])
  print(f"Standard devidation of {feature} is {std}")
# Out:
# Standard devidation of Mthly_HH_Income is 25835.611779092826
# Standard devidation of Mthly_HH_Expense is 11968.704023410388
# Standard devidation of No_of_Fly_Members is 1.502131818450032
# Standard devidation of Emi_or_Rent_Amt is 6178.705366013175

# %% [markdown]
# # 10.Calculate Variance for first 3 columns.

# %%
threecolumns = df.iloc[:,0:3]
for feature in threecolumns:
  var = np.var(df[feature])
  print(f"Variance of {feature} is {var}")
# Out:
# Variance of Mthly_HH_Income is 667478836.0
# Variance of Mthly_HH_Expense is 143249876.0
# Variance of No_of_Fly_Members is 2.2564

# %% [markdown]
# # 11.Calculate the count of Highest qualified member.

# %%
df['Highest_Qualified_Member'].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %% [markdown]
# # 12.Plot the Histogram to count the No_of_Earning_Members

# %%
sns.countplot(x="No_of_Earning_Members",data=df)
# Out:
# <Axes: xlabel='No_of_Earning_Members', ylabel='count'>

# %% [markdown]
# # 13.Suppose you have option to invest in Stock A or Stock B. The stocks • have different expected returns and standard deviations. The expected return of Stock A is 15% and Stock B is 10%. Standard Deviation of the returns of these stocks is 10% and 5% respectively.
#
# Which is better investment?

# %%
stocks_return = [0.15,0.10]
std=[0.1,0.05]

for i in range(len(stocks_return)):
  Coefficient_of_variation = std[i]/stocks_return[i]
  print(Coefficient_of_variation)


#Coefficient_of_variation of A is more than B, So it is better to invest on Stock A than B
# Out:
# 0.6666666666666667
# 0.5
